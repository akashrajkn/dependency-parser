# %%
import torch
from torch.autograd import Variable

# rnn = nn.LSTM(10, 20, 2)
# input = Variable(torch.randn(5, 3, 10))
# h0 = Variable(torch.randn(2, 3, 20))
# c0 = Variable(torch.randn(2, 3, 20))
# output, hn = rnn(input, (h0, c0))

rnn = torch.nn.LSTM(6, 6, 2, bidirectional=True) # (n_input, n_output, n_layers) (hidden layers have size n_output)
inp = Variable(torch.randn(1, 29, 6)) # inp = (1, nwords, lenembedvec)
print(rnn)
print(inp)
output, _ = rnn(inp)
print(output)
# Out:
# LSTM(6, 6, num_layers=2, bidirectional=True)
# Variable containing:
# (0 ,.,.) =
#  -0.9354 -0.8742 -0.2682  1.2111  0.1468  0.8522
#   0.9636 -0.1567 -1.0908  0.4915 -1.1299  0.0485
#  -0.0844 -0.3246 -0.2154 -1.2345  0.2859 -0.4312
#   0.2502  0.1793 -0.3520  0.9275  1.2627 -0.2698
#  -0.1141 -0.3728 -0.3891  0.2782  0.3973  0.1080
#  -1.7911 -0.8009  0.8826 -1.2328 -0.1601 -1.0059
#   0.6677 -0.3679  0.2708  0.3888 -0.1306 -1.0833
#   0.7824  0.6791 -1.1643  1.3816 -0.4647  0.6054
#   0.5816 -0.9403  0.2691  0.5550  0.1981 -0.4145
#  -0.3624  0.0529 -0.9450  1.2148 -0.6828 -1.8745
#  -0.4392 -0.6349  0.4622 -1.5315 -0.1934  0.1106
#   1.7119  0.2440 -0.1508  0.7946 -2.0292 -1.1115
#   0.3771  0.7649 -0.2645  0.0866  0.2462 -0.3571
#  -0.5251  0.2306  1.0288 -0.7537 -1.0162 -0.0424
#   0.1562 -0.8619  1.7894 -1.3094 -0.6484 -0.3673
#   1.1901  0.9060  0.8160 -0.0067 -1.3175 -0.6312
#  -1.6023  0.0570  0.6035 -1.0064  0.4842 -0.0675
# ...
